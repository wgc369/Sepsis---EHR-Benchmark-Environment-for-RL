# %% [markdown]
# - This notebook is an example of benchmarking some RL algorithms from stable_baselines3.
#
# - While running all cells, the learning curve of each algorithm can be visualized via tensorboard.
#
# - To view the learning curves, navigate to current directory in the command prompt and run below command.
#   - tensorboard --logdir ./tensorboard/EHREnv-v0/

# %%
import gymnasium as gym
from EHR_env import EHREnv

import stable_baselines3 as sb3

# %%
gym.register(
    id='EHREnv-v0',
    entry_point='EHR_env:EHREnv',
    max_episode_steps=100,
    kwargs={'model': 'lstm',
            'sofa': 5}
)

# %%
env = gym.make('EHREnv-v0', model='lstm', sofa=5)

# %% [markdown]
# - PPO

# %%
ppo = sb3.PPO("MlpPolicy", 
                env, 
                learning_rate=0.005,
                n_steps=100,
                batch_size=50,
                verbose=1, 
                tensorboard_log="./tensorboard/EHREnv-v0/",
                device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
ppo.learn(total_timesteps=10000, progress_bar=False, log_interval=1, tb_log_name="PPO")
# Out:
# Logging to ./tensorboard/EHREnv-v0/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -4       |
# | time/              |          |
# |    fps             | 16       |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 100      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -3.5        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 200         |
# | train/                  |             |
# |    approx_kl            | 0.043740924 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.201       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.986       |
# |    value_loss           | 0.745       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -4          |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 300         |
# | train/                  |             |
# |    approx_kl            | 0.082466155 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.183       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0455     |
# |    std                  | 0.98        |
# |    value_loss           | 0.568       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -3.5        |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 400         |
# | train/                  |             |
# |    approx_kl            | 0.069703415 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.305       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0396     |
# |    std                  | 1.01        |
# |    value_loss           | 0.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4         |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 5          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 500        |
# | train/                  |            |
# |    approx_kl            | 0.12527837 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.73      |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.277      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0093    |
# |    std                  | 1.01       |
# |    value_loss           | 0.8        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.17      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 6          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 600        |
# | train/                  |            |
# |    approx_kl            | 0.16290343 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.694      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.141      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0467    |
# |    std                  | 1.01       |
# |    value_loss           | 0.52       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -4.86       |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 700         |
# | train/                  |             |
# |    approx_kl            | 0.105772644 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.359       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 1.02        |
# |    value_loss           | 0.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.12      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 8          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 800        |
# | train/                  |            |
# |    approx_kl            | 0.04951047 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | -0.298     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.388      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0325    |
# |    std                  | 0.999      |
# |    value_loss           | 1.15       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.44      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 9          |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 900        |
# | train/                  |            |
# |    approx_kl            | 0.08383325 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.65      |
# |    explained_variance   | -0.129     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.239      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 1          |
# |    value_loss           | 0.966      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.7       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 10         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 1000       |
# | train/                  |            |
# |    approx_kl            | 0.15525998 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.68      |
# |    explained_variance   | 0.203      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.452      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00923    |
# |    std                  | 1          |
# |    value_loss           | 0.917      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.55      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 11         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 1100       |
# | train/                  |            |
# |    approx_kl            | 0.23562008 |
# |    clip_fraction        | 0.513      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.65      |
# |    explained_variance   | -0.126     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.558      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0108    |
# |    std                  | 0.99       |
# |    value_loss           | 1.29       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.25      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 12         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 1200       |
# | train/                  |            |
# |    approx_kl            | 0.12804149 |
# |    clip_fraction        | 0.506      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.62      |
# |    explained_variance   | -0.117     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.116      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0182    |
# |    std                  | 0.986      |
# |    value_loss           | 0.344      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -5.08      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 13         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 1300       |
# | train/                  |            |
# |    approx_kl            | 0.10737888 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.62      |
# |    explained_variance   | 0.0597     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.195      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00302   |
# |    std                  | 0.996      |
# |    value_loss           | 0.43       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.57      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 14         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 1400       |
# | train/                  |            |
# |    approx_kl            | 0.30835903 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.65      |
# |    explained_variance   | 0.118      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.223      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00615   |
# |    std                  | 0.993      |
# |    value_loss           | 0.739      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -4.33       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 15          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 1500        |
# | train/                  |             |
# |    approx_kl            | 0.094781995 |
# |    clip_fraction        | 0.506       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | -0.22       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.247       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0292     |
# |    std                  | 0.982       |
# |    value_loss           | 0.731       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.25      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 16         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.07089993 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.58      |
# |    explained_variance   | 0.27       |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.222      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0244    |
# |    std                  | 0.976      |
# |    value_loss           | 0.712      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.24      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 17         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 1700       |
# | train/                  |            |
# |    approx_kl            | 0.10441545 |
# |    clip_fraction        | 0.523      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.58      |
# |    explained_variance   | -0.115     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.113      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0327    |
# |    std                  | 0.98       |
# |    value_loss           | 0.407      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.17      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 18         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 1800       |
# | train/                  |            |
# |    approx_kl            | 0.06631765 |
# |    clip_fraction        | 0.422      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.59      |
# |    explained_variance   | 0.0468     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.21       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0131    |
# |    std                  | 0.982      |
# |    value_loss           | 0.736      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.21      |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 19         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 1900       |
# | train/                  |            |
# |    approx_kl            | 0.07146966 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.58      |
# |    explained_variance   | 0.0358     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.324      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0217    |
# |    std                  | 0.965      |
# |    value_loss           | 0.99       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -4.2       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 20         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 2000       |
# | train/                  |            |
# |    approx_kl            | 0.23053107 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.51      |
# |    explained_variance   | -0.304     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.282      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0402    |
# |    std                  | 0.966      |
# |    value_loss           | 0.937      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -4.24       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 21          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 2100        |
# | train/                  |             |
# |    approx_kl            | 0.117050596 |
# |    clip_fraction        | 0.535       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | -0.00212    |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.188       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.982       |
# |    value_loss           | 0.503       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -4.09       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 22          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 2200        |
# | train/                  |             |
# |    approx_kl            | 0.100191206 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | -0.12       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.273       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0203      |
# |    std                  | 0.971       |
# |    value_loss           | 0.609       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -3.7       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 23         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 2300       |
# | train/                  |            |
# |    approx_kl            | 0.09661127 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | 0.181      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.106      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.953      |
# |    value_loss           | 0.354      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -3.71       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 24          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 2400        |
# | train/                  |             |
# |    approx_kl            | 0.084001645 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.419       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.957       |
# |    value_loss           | 1.43        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -3.48     |
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 25        |
# |    time_elapsed         | 113       |
# |    total_timesteps      | 2500      |
# | train/                  |           |
# |    approx_kl            | 0.0763247 |
# |    clip_fraction        | 0.389     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.49     |
# |    explained_variance   | 0.0423    |
# |    learning_rate        | 0.005     |
# |    loss                 | 0.282     |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0181   |
# |    std                  | 0.96      |
# |    value_loss           | 0.6       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -3.27       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 26          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 2600        |
# | train/                  |             |
# |    approx_kl            | 0.042127162 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.422       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.94        |
# |    value_loss           | 0.932       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -3.07      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 27         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 2700       |
# | train/                  |            |
# |    approx_kl            | 0.16707453 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.39      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.155      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0551    |
# |    std                  | 0.931      |
# |    value_loss           | 0.557      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.89      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 28         |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 2800       |
# | train/                  |            |
# |    approx_kl            | 0.07385047 |
# |    clip_fraction        | 0.509      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.37      |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.66       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0272    |
# |    std                  | 0.932      |
# |    value_loss           | 1.51       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.86      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 29         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 2900       |
# | train/                  |            |
# |    approx_kl            | 0.20035112 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.903      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0099     |
# |    std                  | 0.955      |
# |    value_loss           | 1.87       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.7       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 30         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 3000       |
# | train/                  |            |
# |    approx_kl            | 0.13418636 |
# |    clip_fraction        | 0.395      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.52      |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.58       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0286    |
# |    std                  | 0.974      |
# |    value_loss           | 1.19       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.58       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 31          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 3100        |
# | train/                  |             |
# |    approx_kl            | 0.054006528 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.537       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.949       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.5       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 32         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 3200       |
# | train/                  |            |
# |    approx_kl            | 0.06371364 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.657      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.419      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 0.934      |
# |    value_loss           | 0.832      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.39      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 33         |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 3300       |
# | train/                  |            |
# |    approx_kl            | 0.11604291 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.38      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.654      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0235    |
# |    std                  | 0.935      |
# |    value_loss           | 1.33       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.29       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 34          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 3400        |
# | train/                  |             |
# |    approx_kl            | 0.057309233 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.45        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.936       |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.4       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 35         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 3500       |
# | train/                  |            |
# |    approx_kl            | 0.08072957 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.39      |
# |    explained_variance   | 0.554      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.671      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0115    |
# |    std                  | 0.938      |
# |    value_loss           | 1.44       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.31      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 36         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 3600       |
# | train/                  |            |
# |    approx_kl            | 0.11740515 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.531      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 0.95       |
# |    value_loss           | 1.38       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.27       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 37          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 3700        |
# | train/                  |             |
# |    approx_kl            | 0.052594997 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.697       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.987       |
# |    value_loss           | 1.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -2.21       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 38          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 3800        |
# | train/                  |             |
# |    approx_kl            | 0.035354912 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.005       |
# |    loss                 | 1.07        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00931    |
# |    std                  | 0.992       |
# |    value_loss           | 1.8         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.13      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 39         |
# |    time_elapsed         | 174        |
# |    total_timesteps      | 3900       |
# | train/                  |            |
# |    approx_kl            | 0.07384451 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.55      |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.622      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0127    |
# |    std                  | 0.964      |
# |    value_loss           | 1.75       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -2.05      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 40         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 4000       |
# | train/                  |            |
# |    approx_kl            | 0.09318005 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.45      |
# |    explained_variance   | 0.441      |
# |    learning_rate        | 0.005      |
# |    loss                 | 1.1        |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.955      |
# |    value_loss           | 2.48       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.98      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 41         |
# |    time_elapsed         | 183        |
# |    total_timesteps      | 4100       |
# | train/                  |            |
# |    approx_kl            | 0.10232182 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 0.536      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.83       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0254    |
# |    std                  | 0.924      |
# |    value_loss           | 1.56       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.88      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 42         |
# |    time_elapsed         | 188        |
# |    total_timesteps      | 4200       |
# | train/                  |            |
# |    approx_kl            | 0.03099215 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.29      |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.911      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00465   |
# |    std                  | 0.914      |
# |    value_loss           | 2.08       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.79      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 43         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 4300       |
# | train/                  |            |
# |    approx_kl            | 0.05390745 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.3       |
# |    explained_variance   | 0.361      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.767      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00422   |
# |    std                  | 0.926      |
# |    value_loss           | 1.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.7        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 44          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 4400        |
# | train/                  |             |
# |    approx_kl            | 0.061522983 |
# |    clip_fraction        | 0.43        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.559       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.935       |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.64      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 45         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 4500       |
# | train/                  |            |
# |    approx_kl            | 0.06585924 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.36      |
# |    explained_variance   | 0.339      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.688      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0261    |
# |    std                  | 0.924      |
# |    value_loss           | 1.66       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.59      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 46         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 4600       |
# | train/                  |            |
# |    approx_kl            | 0.08650819 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.28      |
# |    explained_variance   | 0.569      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.403      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0116    |
# |    std                  | 0.901      |
# |    value_loss           | 0.863      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.53       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 47          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 4700        |
# | train/                  |             |
# |    approx_kl            | 0.029964004 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.568       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.902       |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.54      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 48         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 4800       |
# | train/                  |            |
# |    approx_kl            | 0.11168282 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.28      |
# |    explained_variance   | 0.427      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.858      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0305    |
# |    std                  | 0.921      |
# |    value_loss           | 1.68       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.51      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 49         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 4900       |
# | train/                  |            |
# |    approx_kl            | 0.06086203 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.33      |
# |    explained_variance   | 0.253      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.668      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00236   |
# |    std                  | 0.92       |
# |    value_loss           | 1.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.52      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 50         |
# |    time_elapsed         | 223        |
# |    total_timesteps      | 5000       |
# | train/                  |            |
# |    approx_kl            | 0.10886488 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.33      |
# |    explained_variance   | 0.222      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.514      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0201    |
# |    std                  | 0.93       |
# |    value_loss           | 1.47       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.47      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 51         |
# |    time_elapsed         | 228        |
# |    total_timesteps      | 5100       |
# | train/                  |            |
# |    approx_kl            | 0.02651107 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.37      |
# |    explained_variance   | 0.233      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.336      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00844   |
# |    std                  | 0.926      |
# |    value_loss           | 0.958      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.44       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 52          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.054213386 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.497       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.942       |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -1.38       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 53          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 5300        |
# | train/                  |             |
# |    approx_kl            | 0.038375907 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.788       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00797    |
# |    std                  | 0.946       |
# |    value_loss           | 1.63        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -1.33      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 54         |
# |    time_elapsed         | 241        |
# ...
# |    time_elapsed         | 370        |
# |    total_timesteps      | 8300       |
# | train/                  |            |
# |    approx_kl            | 0.30503193 |
# |    clip_fraction        | 0.659      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.93      |
# |    explained_variance   | 0.667      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0448     |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0143    |
# |    std                  | 0.854      |
# |    value_loss           | 0.115      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.345     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 84         |
# |    time_elapsed         | 375        |
# |    total_timesteps      | 8400       |
# | train/                  |            |
# |    approx_kl            | 0.04003971 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | 0.642      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.00637    |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0192    |
# |    std                  | 0.858      |
# |    value_loss           | 0.112      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.329      |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 85          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 8500        |
# | train/                  |             |
# |    approx_kl            | 0.108026505 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.005       |
# |    loss                 | -0.00516    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0448     |
# |    std                  | 0.841       |
# |    value_loss           | 0.131       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.314     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 86         |
# |    time_elapsed         | 384        |
# |    total_timesteps      | 8600       |
# | train/                  |            |
# |    approx_kl            | 0.21917906 |
# |    clip_fraction        | 0.603      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.94      |
# |    explained_variance   | -0.00898   |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0676     |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0397    |
# |    std                  | 0.841      |
# |    value_loss           | 0.219      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.287     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 87         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 8700       |
# | train/                  |            |
# |    approx_kl            | 0.03610796 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.91      |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.005      |
# |    loss                 | -0.024     |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.024     |
# |    std                  | 0.826      |
# |    value_loss           | 0.237      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.273     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 88         |
# |    time_elapsed         | 392        |
# |    total_timesteps      | 8800       |
# | train/                  |            |
# |    approx_kl            | 0.07171069 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.9       |
# |    explained_variance   | 0.645      |
# |    learning_rate        | 0.005      |
# |    loss                 | -0.0353    |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.848      |
# |    value_loss           | 0.0933     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.236     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 89         |
# |    time_elapsed         | 397        |
# |    total_timesteps      | 8900       |
# | train/                  |            |
# |    approx_kl            | 0.36797222 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0418     |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.029     |
# |    std                  | 0.854      |
# |    value_loss           | 0.199      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -0.256    |
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 90        |
# |    time_elapsed         | 401       |
# |    total_timesteps      | 9000      |
# | train/                  |           |
# |    approx_kl            | 0.0780154 |
# |    clip_fraction        | 0.399     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.94     |
# |    explained_variance   | 0.714     |
# |    learning_rate        | 0.005     |
# |    loss                 | 0.0477    |
# |    n_updates            | 890       |
# |    policy_gradient_loss | -0.0279   |
# |    std                  | 0.849     |
# |    value_loss           | 0.232     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.22      |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 91         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 9100       |
# | train/                  |            |
# |    approx_kl            | 0.07301542 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.97      |
# |    explained_variance   | -0.0391    |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0641     |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.0304    |
# |    std                  | 0.866      |
# |    value_loss           | 0.379      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.207     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 92         |
# |    time_elapsed         | 410        |
# |    total_timesteps      | 9200       |
# | train/                  |            |
# |    approx_kl            | 0.05238521 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | 0.499      |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0462     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0335    |
# |    std                  | 0.853      |
# |    value_loss           | 0.262      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.172     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 93         |
# |    time_elapsed         | 414        |
# |    total_timesteps      | 9300       |
# | train/                  |            |
# |    approx_kl            | 0.08758326 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.9       |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.005      |
# |    loss                 | -0.0188    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0467    |
# |    std                  | 0.832      |
# |    value_loss           | 0.0948     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.16       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 94          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 9400        |
# | train/                  |             |
# |    approx_kl            | 0.033372212 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.0539      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.853       |
# |    value_loss           | 0.204       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -0.137     |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 95         |
# |    time_elapsed         | 423        |
# |    total_timesteps      | 9500       |
# | train/                  |            |
# |    approx_kl            | 0.29920894 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | -0.061     |
# |    learning_rate        | 0.005      |
# |    loss                 | 0.0253     |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0476    |
# |    std                  | 0.839      |
# |    value_loss           | 0.297      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.115      |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 96          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.053368974 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.345       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.832       |
# |    value_loss           | 0.825       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.103      |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 97          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 9700        |
# | train/                  |             |
# |    approx_kl            | 0.045458205 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.005       |
# |    loss                 | -0.022      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.825       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -0.0816   |
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 98        |
# |    time_elapsed         | 436       |
# |    total_timesteps      | 9800      |
# | train/                  |           |
# |    approx_kl            | 0.1160128 |
# |    clip_fraction        | 0.453     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.8      |
# |    explained_variance   | 0.771     |
# |    learning_rate        | 0.005     |
# |    loss                 | 0.000148  |
# |    n_updates            | 970       |
# |    policy_gradient_loss | -0.0258   |
# |    std                  | 0.82      |
# |    value_loss           | 0.156     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -0.0707   |
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 99        |
# |    time_elapsed         | 441       |
# |    total_timesteps      | 9900      |
# | train/                  |           |
# |    approx_kl            | 0.2656021 |
# |    clip_fraction        | 0.555     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.77     |
# |    explained_variance   | 0.724     |
# |    learning_rate        | 0.005     |
# |    loss                 | 0.233     |
# |    n_updates            | 980       |
# |    policy_gradient_loss | 0.0523    |
# |    std                  | 0.816     |
# |    value_loss           | 0.226     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.06       |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 100         |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.105574384 |
# |    clip_fraction        | 0.568       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.005       |
# |    loss                 | 0.0307      |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.792       |
# |    value_loss           | 0.117       |
# -----------------------------------------

# %% [markdown]
# - DDPG

# %%
del env
env = gym.make('EHREnv-v0', model='lstm', sofa=5)

# %%
ddpg = sb3.DDPG("MlpPolicy", 
                env, 
                learning_rate=0.01,
                buffer_size=100,
                learning_starts=100,
                batch_size=64,
                train_freq=1,
                verbose=1, 
                tensorboard_log="./tensorboard/EHREnv-v0/",
                device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
ddpg.learn(total_timesteps=10000, progress_bar=False, log_interval=1, tb_log_name="DDPG")
# Out:
# Logging to ./tensorboard/EHREnv-v0/DDPG_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -7       |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 22       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -5       |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 19       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 1.19e+03 |
# |    critic_loss     | 2.03e+03 |
# |    learning_rate   | 0.01     |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -4.33    |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 18       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 300      |
# | train/             |          |
# |    actor_loss      | 771      |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 199      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -4       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 18       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 812      |
# |    critic_loss     | 45.4     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.8     |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 18       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 798      |
# |    critic_loss     | 0.478    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.67    |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 18       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 785      |
# |    critic_loss     | 0.624    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.57    |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 17       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 700      |
# | train/             |          |
# |    actor_loss      | 775      |
# |    critic_loss     | 1.42     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.5     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 17       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 770      |
# |    critic_loss     | 0.449    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.44    |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 17       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 763      |
# |    critic_loss     | 0.759    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.4     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 17       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 757      |
# |    critic_loss     | 2.11     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.36    |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 16       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 1100     |
# | train/             |          |
# |    actor_loss      | 761      |
# |    critic_loss     | 47.6     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.33    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 16       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 748      |
# |    critic_loss     | 43.6     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.31    |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 16       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 1300     |
# | train/             |          |
# |    actor_loss      | 739      |
# |    critic_loss     | 501      |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.29    |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 16       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | 744      |
# |    critic_loss     | 0.342    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.27    |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 16       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | 740      |
# |    critic_loss     | 0.17     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.25    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 16       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | 737      |
# |    critic_loss     | 0.685    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.24    |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 15       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 1700     |
# | train/             |          |
# |    actor_loss      | 734      |
# |    critic_loss     | 3.91     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.22    |
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 15       |
# |    time_elapsed    | 113      |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 730      |
# |    critic_loss     | 1.39     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.21    |
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 15       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 1900     |
# | train/             |          |
# |    actor_loss      | 725      |
# |    critic_loss     | 84.1     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.2     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 15       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 725      |
# |    critic_loss     | 0.128    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.19    |
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 15       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 2100     |
# | train/             |          |
# |    actor_loss      | 722      |
# |    critic_loss     | 0.0502   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.18    |
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 15       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | 718      |
# |    critic_loss     | 0.748    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.17    |
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 15       |
# |    time_elapsed    | 146      |
# |    total_timesteps | 2300     |
# | train/             |          |
# |    actor_loss      | 714      |
# |    critic_loss     | 1.57     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.17    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 15       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 712      |
# |    critic_loss     | 0.174    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.16    |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 15       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | 707      |
# |    critic_loss     | 4.52     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.15    |
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 15       |
# |    time_elapsed    | 167      |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | 711      |
# |    critic_loss     | 40.5     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.15    |
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 15       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 702      |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.14    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 15       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | 699      |
# |    critic_loss     | 0.0955   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.14    |
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 15       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 2900     |
# | train/             |          |
# |    actor_loss      | 697      |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.13    |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 15       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 691      |
# |    critic_loss     | 0.196    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.13    |
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 15       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 3100     |
# | train/             |          |
# |    actor_loss      | 683      |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.12    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 15       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 690      |
# |    critic_loss     | 42.1     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.12    |
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 15       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 3300     |
# | train/             |          |
# |    actor_loss      | -6.1     |
# |    critic_loss     | 154      |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.12    |
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 15       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 35.7     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.11    |
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 15       |
# |    time_elapsed    | 228      |
# |    total_timesteps | 3500     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 26.5     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.11    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 15       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 7.03     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.11    |
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 15       |
# |    time_elapsed    | 241      |
# |    total_timesteps | 3700     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.314    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.11    |
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 15       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.263    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.1     |
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 15       |
# |    time_elapsed    | 255      |
# |    total_timesteps | 3900     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.147    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.1     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 15       |
# |    time_elapsed    | 262      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 8.89     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.1     |
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 15       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 4100     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 1.2      |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.1     |
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 15       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.308    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 15       |
# |    time_elapsed    | 283      |
# |    total_timesteps | 4300     |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 2.96     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 15       |
# |    time_elapsed    | 290      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.371    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 15       |
# |    time_elapsed    | 297      |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.33     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 15       |
# |    time_elapsed    | 304      |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.0757   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.09    |
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 15       |
# |    time_elapsed    | 311      |
# |    total_timesteps | 4700     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 15       |
# |    time_elapsed    | 318      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 2.01     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 15       |
# |    time_elapsed    | 324      |
# |    total_timesteps | 4900     |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.024    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 15       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.0537   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 51       |
# |    fps             | 15       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 5100     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.938    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 15       |
# |    time_elapsed    | 344      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.876    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.08    |
# | time/              |          |
# |    episodes        | 53       |
# |    fps             | 15       |
# |    time_elapsed    | 352      |
# |    total_timesteps | 5300     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.223    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 54       |
# |    fps             | 15       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 1.23     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 55       |
# |    fps             | 15       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 5500     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.702    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 15       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.0038   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 57       |
# |    fps             | 15       |
# |    time_elapsed    | 379      |
# |    total_timesteps | 5700     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 0.192    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 58       |
# |    fps             | 15       |
# |    time_elapsed    | 386      |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.169    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 59       |
# |    fps             | 14       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 5900     |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.24     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 14       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.0222   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.07    |
# | time/              |          |
# |    episodes        | 61       |
# |    fps             | 14       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 6100     |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.127    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 62       |
# |    fps             | 14       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.458    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 63       |
# |    fps             | 14       |
# |    time_elapsed    | 421      |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.443    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 14       |
# |    time_elapsed    | 428      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.411    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 65       |
# |    fps             | 14       |
# |    time_elapsed    | 435      |
# |    total_timesteps | 6500     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.197    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 66       |
# |    fps             | 14       |
# |    time_elapsed    | 442      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.113    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 67       |
# |    fps             | 14       |
# |    time_elapsed    | 449      |
# |    total_timesteps | 6700     |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.525    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 14       |
# |    time_elapsed    | 456      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 0.248    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 69       |
# |    fps             | 14       |
# |    time_elapsed    | 463      |
# |    total_timesteps | 6900     |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 0.162    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 14       |
# |    time_elapsed    | 470      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.483    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 71       |
# |    fps             | 14       |
# |    time_elapsed    | 476      |
# |    total_timesteps | 7100     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.232    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.06    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 14       |
# |    time_elapsed    | 483      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.272    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 73       |
# |    fps             | 14       |
# |    time_elapsed    | 491      |
# |    total_timesteps | 7300     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.028    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 74       |
# |    fps             | 14       |
# |    time_elapsed    | 497      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.342    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 75       |
# |    fps             | 14       |
# |    time_elapsed    | 504      |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.162    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 14       |
# |    time_elapsed    | 511      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.448    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 77       |
# |    fps             | 14       |
# |    time_elapsed    | 518      |
# |    total_timesteps | 7700     |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.207    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 78       |
# |    fps             | 14       |
# |    time_elapsed    | 525      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.00351  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 79       |
# |    fps             | 14       |
# |    time_elapsed    | 532      |
# |    total_timesteps | 7900     |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.0763   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 14       |
# |    time_elapsed    | 539      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.141    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 81       |
# |    fps             | 14       |
# |    time_elapsed    | 546      |
# |    total_timesteps | 8100     |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.0665   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 82       |
# |    fps             | 14       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.225    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 83       |
# |    fps             | 14       |
# |    time_elapsed    | 560      |
# |    total_timesteps | 8300     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.0209   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 14       |
# |    time_elapsed    | 567      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.101    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 85       |
# |    fps             | 14       |
# |    time_elapsed    | 574      |
# |    total_timesteps | 8500     |
# | train/             |          |
# |    actor_loss      | -12.7    |
# |    critic_loss     | 0.14     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 86       |
# |    fps             | 14       |
# |    time_elapsed    | 580      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.0252   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 87       |
# |    fps             | 14       |
# |    time_elapsed    | 588      |
# |    total_timesteps | 8700     |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.0784   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.05    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 14       |
# |    time_elapsed    | 595      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.176    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 89       |
# |    fps             | 14       |
# |    time_elapsed    | 602      |
# |    total_timesteps | 8900     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.0148   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 14       |
# |    time_elapsed    | 609      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.103    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 91       |
# |    fps             | 14       |
# |    time_elapsed    | 616      |
# |    total_timesteps | 9100     |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.183    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 14       |
# |    time_elapsed    | 623      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.162    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 93       |
# |    fps             | 14       |
# |    time_elapsed    | 630      |
# |    total_timesteps | 9300     |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.0242   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 94       |
# |    fps             | 14       |
# |    time_elapsed    | 637      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.12     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 95       |
# |    fps             | 14       |
# |    time_elapsed    | 644      |
# |    total_timesteps | 9500     |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.00703  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 14       |
# |    time_elapsed    | 651      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.291    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 97       |
# |    fps             | 14       |
# |    time_elapsed    | 658      |
# |    total_timesteps | 9700     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.0088   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 98       |
# |    fps             | 14       |
# |    time_elapsed    | 665      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.749    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 99       |
# |    fps             | 14       |
# |    time_elapsed    | 671      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.21     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -3.04    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 14       |
# |    time_elapsed    | 678      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -9.95    |
# |    critic_loss     | 2.41     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9899     |
# ---------------------------------

# %% [markdown]
# - SAC

# %%
del env
env = gym.make('EHREnv-v0', model='lstm', sofa=5)

# %%
sac = sb3.SAC("MlpPolicy", 
                env, 
                learning_rate=0.005,
                learning_starts=100,
                buffer_size=100,
                batch_size=64,
                train_freq=1,
                verbose=1, 
                tensorboard_log="./tensorboard/EHREnv-v0/",
                device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
sac.learn(total_timesteps=10000, progress_bar=False, log_interval=1, tb_log_name="SAC")
# Out:
# Logging to ./tensorboard/EHREnv-v0/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -5       |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 23       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -1.5     |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 18       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 429      |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 1.6      |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.005    |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -0.667   |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 17       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 300      |
# | train/             |          |
# |    actor_loss      | 580      |
# |    critic_loss     | 20.3     |
# |    ent_coef        | 2.63     |
# |    ent_coef_loss   | -36.2    |
# |    learning_rate   | 0.005    |
# |    n_updates       | 199      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -0.25    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 17       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 788      |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 4.32     |
# |    ent_coef_loss   | -54.7    |
# |    learning_rate   | 0.005    |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 16       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 1.13e+03 |
# |    critic_loss     | 89.3     |
# |    ent_coef        | 7.1      |
# |    ent_coef_loss   | -73.9    |
# |    learning_rate   | 0.005    |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.167    |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 16       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 1.66e+03 |
# |    critic_loss     | 467      |
# |    ent_coef        | 11.7     |
# |    ent_coef_loss   | -93.1    |
# |    learning_rate   | 0.005    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.286    |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 16       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 700      |
# | train/             |          |
# |    actor_loss      | 2.54e+03 |
# |    critic_loss     | 1.61e+03 |
# |    ent_coef        | 19.2     |
# |    ent_coef_loss   | -111     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.375    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 16       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 4.03e+03 |
# |    critic_loss     | 1.97e+03 |
# |    ent_coef        | 31.7     |
# |    ent_coef_loss   | -130     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.444    |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 16       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 6.49e+03 |
# |    critic_loss     | 1.35e+04 |
# |    ent_coef        | 52.2     |
# |    ent_coef_loss   | -149     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 15       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 1.04e+04 |
# |    critic_loss     | 4.74e+04 |
# |    ent_coef        | 86.1     |
# |    ent_coef_loss   | -169     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.545    |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 15       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 1100     |
# | train/             |          |
# |    actor_loss      | 1.68e+04 |
# |    critic_loss     | 3.04e+04 |
# |    ent_coef        | 142      |
# |    ent_coef_loss   | -188     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.583    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 15       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 2.7e+04  |
# |    critic_loss     | 1.88e+05 |
# |    ent_coef        | 234      |
# |    ent_coef_loss   | -204     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.615    |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 14       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 1300     |
# | train/             |          |
# |    actor_loss      | 4.46e+04 |
# |    critic_loss     | 5.57e+05 |
# |    ent_coef        | 385      |
# |    ent_coef_loss   | -226     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.643    |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 14       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | 7.27e+04 |
# |    critic_loss     | 1.77e+06 |
# |    ent_coef        | 635      |
# |    ent_coef_loss   | -246     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.667    |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 14       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | 1.19e+05 |
# |    critic_loss     | 2.93e+06 |
# |    ent_coef        | 1.05e+03 |
# |    ent_coef_loss   | -260     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.688    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 14       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | 1.97e+05 |
# |    critic_loss     | 6.34e+06 |
# |    ent_coef        | 1.72e+03 |
# |    ent_coef_loss   | -280     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.706    |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 14       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 1700     |
# | train/             |          |
# |    actor_loss      | 3.23e+05 |
# |    critic_loss     | 2.37e+07 |
# |    ent_coef        | 2.84e+03 |
# |    ent_coef_loss   | -297     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.722    |
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 14       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 5.26e+05 |
# |    critic_loss     | 5.31e+07 |
# |    ent_coef        | 4.68e+03 |
# |    ent_coef_loss   | -316     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.737    |
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 14       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 1900     |
# | train/             |          |
# |    actor_loss      | 8.69e+05 |
# |    critic_loss     | 1.87e+08 |
# |    ent_coef        | 7.72e+03 |
# |    ent_coef_loss   | -336     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.75     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 13       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 1.45e+06 |
# |    critic_loss     | 2.44e+08 |
# |    ent_coef        | 1.27e+04 |
# |    ent_coef_loss   | -359     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.762    |
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 13       |
# |    time_elapsed    | 151      |
# |    total_timesteps | 2100     |
# | train/             |          |
# |    actor_loss      | 2.35e+06 |
# |    critic_loss     | 6.6e+08  |
# |    ent_coef        | 2.1e+04  |
# |    ent_coef_loss   | -375     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.773    |
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 13       |
# |    time_elapsed    | 158      |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | 3.88e+06 |
# |    critic_loss     | 4.66e+09 |
# |    ent_coef        | 3.46e+04 |
# |    ent_coef_loss   | -391     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.783    |
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 13       |
# |    time_elapsed    | 167      |
# |    total_timesteps | 2300     |
# | train/             |          |
# |    actor_loss      | 6.42e+06 |
# |    critic_loss     | 5.55e+09 |
# |    ent_coef        | 5.7e+04  |
# |    ent_coef_loss   | -412     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.792    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 13       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 1.07e+07 |
# |    critic_loss     | 2.24e+10 |
# |    ent_coef        | 9.4e+04  |
# |    ent_coef_loss   | -432     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 13       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | 1.75e+07 |
# |    critic_loss     | 4.39e+10 |
# |    ent_coef        | 1.55e+05 |
# |    ent_coef_loss   | -450     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.808    |
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 13       |
# |    time_elapsed    | 190      |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | 2.87e+07 |
# |    critic_loss     | 1.25e+11 |
# |    ent_coef        | 2.56e+05 |
# |    ent_coef_loss   | -468     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.815    |
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 13       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 4.73e+07 |
# |    critic_loss     | 2.66e+11 |
# |    ent_coef        | 4.22e+05 |
# |    ent_coef_loss   | -486     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.821    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 13       |
# |    time_elapsed    | 207      |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | 7.82e+07 |
# |    critic_loss     | 7.4e+11  |
# |    ent_coef        | 6.95e+05 |
# |    ent_coef_loss   | -508     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.828    |
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 13       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 2900     |
# | train/             |          |
# |    actor_loss      | 1.29e+08 |
# |    critic_loss     | 3.13e+12 |
# |    ent_coef        | 1.15e+06 |
# |    ent_coef_loss   | -521     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.833    |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 13       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 2.13e+08 |
# |    critic_loss     | 5.53e+12 |
# |    ent_coef        | 1.89e+06 |
# |    ent_coef_loss   | -541     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.839    |
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 13       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 3100     |
# | train/             |          |
# |    actor_loss      | 3.51e+08 |
# |    critic_loss     | 2.66e+13 |
# |    ent_coef        | 3.11e+06 |
# |    ent_coef_loss   | -561     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.844    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 13       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 5.79e+08 |
# |    critic_loss     | 5.66e+13 |
# |    ent_coef        | 5.13e+06 |
# |    ent_coef_loss   | -581     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.848    |
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 13       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 3300     |
# | train/             |          |
# |    actor_loss      | 9.51e+08 |
# |    critic_loss     | 1.73e+14 |
# |    ent_coef        | 8.46e+06 |
# |    ent_coef_loss   | -599     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.853    |
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 13       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | 1.57e+09 |
# |    critic_loss     | 5.28e+14 |
# |    ent_coef        | 1.39e+07 |
# |    ent_coef_loss   | -617     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.857    |
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 13       |
# |    time_elapsed    | 261      |
# |    total_timesteps | 3500     |
# | train/             |          |
# |    actor_loss      | 2.6e+09  |
# |    critic_loss     | 1.12e+15 |
# |    ent_coef        | 2.3e+07  |
# |    ent_coef_loss   | -644     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.861    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 13       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 4.25e+09 |
# |    critic_loss     | 3.64e+15 |
# |    ent_coef        | 3.79e+07 |
# |    ent_coef_loss   | -652     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.865    |
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 13       |
# |    time_elapsed    | 277      |
# |    total_timesteps | 3700     |
# | train/             |          |
# |    actor_loss      | 7e+09    |
# |    critic_loss     | 1.62e+16 |
# |    ent_coef        | 6.25e+07 |
# |    ent_coef_loss   | -670     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.868    |
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 13       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | 1.16e+10 |
# |    critic_loss     | 2.11e+16 |
# |    ent_coef        | 1.03e+08 |
# |    ent_coef_loss   | -696     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.872    |
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 13       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 3900     |
# | train/             |          |
# |    actor_loss      | 1.91e+10 |
# |    critic_loss     | 7.32e+16 |
# |    ent_coef        | 1.7e+08  |
# |    ent_coef_loss   | -711     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.875    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 13       |
# |    time_elapsed    | 301      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 3.15e+10 |
# |    critic_loss     | 1.87e+17 |
# |    ent_coef        | 2.8e+08  |
# |    ent_coef_loss   | -731     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.878    |
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 13       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 4100     |
# | train/             |          |
# |    actor_loss      | 5.17e+10 |
# |    critic_loss     | 1.68e+18 |
# |    ent_coef        | 4.62e+08 |
# |    ent_coef_loss   | -753     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.881    |
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 13       |
# |    time_elapsed    | 316      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | 8.42e+10 |
# |    critic_loss     | 2.3e+19  |
# |    ent_coef        | 7.62e+08 |
# |    ent_coef_loss   | -770     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.884    |
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 13       |
# |    time_elapsed    | 325      |
# |    total_timesteps | 4300     |
# | train/             |          |
# |    actor_loss      | 1.34e+11 |
# |    critic_loss     | 2.31e+20 |
# |    ent_coef        | 1.26e+09 |
# |    ent_coef_loss   | -790     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.886    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 13       |
# |    time_elapsed    | 333      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | 2.06e+11 |
# |    critic_loss     | 1.6e+21  |
# |    ent_coef        | 2.07e+09 |
# |    ent_coef_loss   | -812     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.889    |
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 13       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 3.06e+11 |
# |    critic_loss     | 8.56e+21 |
# |    ent_coef        | 3.41e+09 |
# |    ent_coef_loss   | -828     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.891    |
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 13       |
# |    time_elapsed    | 348      |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | 4.33e+11 |
# |    critic_loss     | 3.59e+22 |
# |    ent_coef        | 5.63e+09 |
# |    ent_coef_loss   | -838     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.894    |
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 13       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 4700     |
# | train/             |          |
# |    actor_loss      | 6.17e+11 |
# |    critic_loss     | 1.23e+23 |
# |    ent_coef        | 9.28e+09 |
# |    ent_coef_loss   | -858     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.896    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 13       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 8.98e+11 |
# |    critic_loss     | 3.64e+23 |
# |    ent_coef        | 1.53e+10 |
# |    ent_coef_loss   | -873     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.898    |
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 13       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 4900     |
# | train/             |          |
# |    actor_loss      | 1.35e+12 |
# |    critic_loss     | 1.04e+24 |
# |    ent_coef        | 2.52e+10 |
# |    ent_coef_loss   | -901     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.9      |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 13       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 2.04e+12 |
# |    critic_loss     | 2.97e+24 |
# |    ent_coef        | 4.16e+10 |
# |    ent_coef_loss   | -919     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.902    |
# | time/              |          |
# |    episodes        | 51       |
# |    fps             | 13       |
# |    time_elapsed    | 388      |
# |    total_timesteps | 5100     |
# | train/             |          |
# |    actor_loss      | 3.19e+12 |
# |    critic_loss     | 7.98e+24 |
# |    ent_coef        | 6.86e+10 |
# |    ent_coef_loss   | -937     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.904    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 13       |
# |    time_elapsed    | 396      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | 5.08e+12 |
# |    critic_loss     | 2.18e+25 |
# |    ent_coef        | 1.13e+11 |
# |    ent_coef_loss   | -962     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.906    |
# | time/              |          |
# |    episodes        | 53       |
# |    fps             | 13       |
# |    time_elapsed    | 405      |
# |    total_timesteps | 5300     |
# | train/             |          |
# |    actor_loss      | 8.15e+12 |
# |    critic_loss     | 5.96e+25 |
# |    ent_coef        | 1.87e+11 |
# |    ent_coef_loss   | -981     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 5199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.907    |
# | time/              |          |
# |    episodes        | 54       |
# |    fps             | 13       |
# |    time_elapsed    | 413      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | 1.31e+13 |
# |    critic_loss     | 1.63e+26 |
# |    ent_coef        | 3.07e+11 |
# |    ent_coef_loss   | -992     |
# |    learning_rate   | 0.005    |
# |    n_updates       | 5299     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.909     |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 13        |
# |    time_elapsed    | 422       |
# |    total_timesteps | 5500      |
# | train/             |           |
# |    actor_loss      | 2.14e+13  |
# |    critic_loss     | 4.34e+26  |
# |    ent_coef        | 5.07e+11  |
# |    ent_coef_loss   | -1.01e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5399      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.911     |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 13        |
# |    time_elapsed    | 430       |
# |    total_timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 3.51e+13  |
# |    critic_loss     | 1.18e+27  |
# |    ent_coef        | 8.36e+11  |
# |    ent_coef_loss   | -1.03e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.912     |
# | time/              |           |
# |    episodes        | 57        |
# |    fps             | 12        |
# |    time_elapsed    | 439       |
# |    total_timesteps | 5700      |
# | train/             |           |
# |    actor_loss      | 5.77e+13  |
# |    critic_loss     | 3.17e+27  |
# |    ent_coef        | 1.38e+12  |
# |    ent_coef_loss   | -1.05e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5599      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.914     |
# | time/              |           |
# |    episodes        | 58        |
# |    fps             | 12        |
# |    time_elapsed    | 449       |
# |    total_timesteps | 5800      |
# | train/             |           |
# |    actor_loss      | 9.44e+13  |
# |    critic_loss     | 8.73e+27  |
# |    ent_coef        | 2.27e+12  |
# |    ent_coef_loss   | -1.06e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.915     |
# | time/              |           |
# |    episodes        | 59        |
# |    fps             | 12        |
# |    time_elapsed    | 457       |
# |    total_timesteps | 5900      |
# | train/             |           |
# |    actor_loss      | 1.56e+14  |
# |    critic_loss     | 2.37e+28  |
# |    ent_coef        | 3.74e+12  |
# |    ent_coef_loss   | -1.09e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5799      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.917     |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 12        |
# |    time_elapsed    | 465       |
# |    total_timesteps | 6000      |
# | train/             |           |
# |    actor_loss      | 2.57e+14  |
# |    critic_loss     | 6.44e+28  |
# |    ent_coef        | 6.17e+12  |
# |    ent_coef_loss   | -1.11e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.918     |
# | time/              |           |
# |    episodes        | 61        |
# |    fps             | 12        |
# |    time_elapsed    | 473       |
# |    total_timesteps | 6100      |
# | train/             |           |
# |    actor_loss      | 4.23e+14  |
# |    critic_loss     | 1.75e+29  |
# |    ent_coef        | 1.02e+13  |
# |    ent_coef_loss   | -1.13e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 5999      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.919     |
# | time/              |           |
# |    episodes        | 62        |
# |    fps             | 12        |
# |    time_elapsed    | 481       |
# |    total_timesteps | 6200      |
# | train/             |           |
# |    actor_loss      | 7e+14     |
# |    critic_loss     | 4.77e+29  |
# |    ent_coef        | 1.68e+13  |
# |    ent_coef_loss   | -1.15e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.921     |
# | time/              |           |
# |    episodes        | 63        |
# |    fps             | 12        |
# |    time_elapsed    | 489       |
# |    total_timesteps | 6300      |
# | train/             |           |
# |    actor_loss      | 1.16e+15  |
# |    critic_loss     | 1.29e+30  |
# |    ent_coef        | 2.77e+13  |
# |    ent_coef_loss   | -1.17e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6199      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.922     |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 12        |
# |    time_elapsed    | 497       |
# |    total_timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 1.9e+15   |
# |    critic_loss     | 3.55e+30  |
# |    ent_coef        | 4.56e+13  |
# |    ent_coef_loss   | -1.18e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.923     |
# | time/              |           |
# |    episodes        | 65        |
# |    fps             | 12        |
# |    time_elapsed    | 505       |
# |    total_timesteps | 6500      |
# | train/             |           |
# |    actor_loss      | 3.15e+15  |
# |    critic_loss     | 9.73e+30  |
# |    ent_coef        | 7.52e+13  |
# |    ent_coef_loss   | -1.21e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6399      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.924     |
# | time/              |           |
# |    episodes        | 66        |
# |    fps             | 12        |
# |    time_elapsed    | 513       |
# |    total_timesteps | 6600      |
# | train/             |           |
# |    actor_loss      | 5.15e+15  |
# |    critic_loss     | 2.6e+31   |
# |    ent_coef        | 1.24e+14  |
# |    ent_coef_loss   | -1.22e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.925     |
# | time/              |           |
# |    episodes        | 67        |
# |    fps             | 12        |
# |    time_elapsed    | 520       |
# |    total_timesteps | 6700      |
# | train/             |           |
# |    actor_loss      | 8.46e+15  |
# |    critic_loss     | 7.11e+31  |
# |    ent_coef        | 2.04e+14  |
# |    ent_coef_loss   | -1.23e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6599      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.926     |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 12        |
# |    time_elapsed    | 528       |
# |    total_timesteps | 6800      |
# | train/             |           |
# |    actor_loss      | 1.4e+16   |
# |    critic_loss     | 1.91e+32  |
# |    ent_coef        | 3.37e+14  |
# |    ent_coef_loss   | -1.26e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.928     |
# | time/              |           |
# |    episodes        | 69        |
# |    fps             | 12        |
# |    time_elapsed    | 536       |
# |    total_timesteps | 6900      |
# | train/             |           |
# |    actor_loss      | 2.33e+16  |
# |    critic_loss     | 5.29e+32  |
# |    ent_coef        | 5.55e+14  |
# |    ent_coef_loss   | -1.29e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6799      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.929    |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 12       |
# |    time_elapsed    | 544      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | 3.82e+16 |
# |    critic_loss     | 1.41e+33 |
# |    ent_coef        | 9.16e+14 |
# |    ent_coef_loss   | -1.3e+03 |
# |    learning_rate   | 0.005    |
# |    n_updates       | 6899     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.93      |
# | time/              |           |
# |    episodes        | 71        |
# |    fps             | 12        |
# |    time_elapsed    | 553       |
# |    total_timesteps | 7100      |
# | train/             |           |
# |    actor_loss      | 6.27e+16  |
# |    critic_loss     | 3.87e+33  |
# |    ent_coef        | 1.51e+15  |
# |    ent_coef_loss   | -1.31e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 6999      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.931     |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 12        |
# |    time_elapsed    | 560       |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 1.04e+17  |
# |    critic_loss     | 1.05e+34  |
# |    ent_coef        | 2.49e+15  |
# |    ent_coef_loss   | -1.33e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.932     |
# | time/              |           |
# |    episodes        | 73        |
# |    fps             | 12        |
# |    time_elapsed    | 568       |
# |    total_timesteps | 7300      |
# | train/             |           |
# |    actor_loss      | 1.69e+17  |
# |    critic_loss     | 2.83e+34  |
# |    ent_coef        | 4.11e+15  |
# |    ent_coef_loss   | -1.34e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7199      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.932     |
# | time/              |           |
# |    episodes        | 74        |
# |    fps             | 12        |
# |    time_elapsed    | 577       |
# |    total_timesteps | 7400      |
# | train/             |           |
# |    actor_loss      | 2.81e+17  |
# |    critic_loss     | 7.84e+34  |
# |    ent_coef        | 6.77e+15  |
# |    ent_coef_loss   | -1.37e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.933     |
# | time/              |           |
# |    episodes        | 75        |
# |    fps             | 12        |
# |    time_elapsed    | 584       |
# |    total_timesteps | 7500      |
# | train/             |           |
# |    actor_loss      | 4.6e+17   |
# |    critic_loss     | 2.13e+35  |
# |    ent_coef        | 1.12e+16  |
# |    ent_coef_loss   | -1.38e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7399      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.934    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 12       |
# |    time_elapsed    | 593      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | 7.59e+17 |
# |    critic_loss     | 5.79e+35 |
# |    ent_coef        | 1.84e+16 |
# |    ent_coef_loss   | -1.4e+03 |
# |    learning_rate   | 0.005    |
# |    n_updates       | 7499     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.935     |
# | time/              |           |
# |    episodes        | 77        |
# |    fps             | 12        |
# |    time_elapsed    | 600       |
# |    total_timesteps | 7700      |
# | train/             |           |
# |    actor_loss      | 1.26e+18  |
# |    critic_loss     | 1.56e+36  |
# |    ent_coef        | 3.03e+16  |
# |    ent_coef_loss   | -1.42e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7599      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.936     |
# | time/              |           |
# |    episodes        | 78        |
# |    fps             | 12        |
# |    time_elapsed    | 609       |
# |    total_timesteps | 7800      |
# | train/             |           |
# |    actor_loss      | 2.08e+18  |
# |    critic_loss     | 4.24e+36  |
# |    ent_coef        | 5e+16     |
# |    ent_coef_loss   | -1.45e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.937     |
# | time/              |           |
# |    episodes        | 79        |
# |    fps             | 12        |
# |    time_elapsed    | 617       |
# |    total_timesteps | 7900      |
# | train/             |           |
# |    actor_loss      | 3.41e+18  |
# |    critic_loss     | inf       |
# |    ent_coef        | 8.24e+16  |
# |    ent_coef_loss   | -1.46e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7799      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.938     |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 12        |
# |    time_elapsed    | 624       |
# |    total_timesteps | 8000      |
# | train/             |           |
# |    actor_loss      | 5.66e+18  |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.36e+17  |
# |    ent_coef_loss   | -1.48e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.938     |
# | time/              |           |
# |    episodes        | 81        |
# |    fps             | 12        |
# |    time_elapsed    | 633       |
# |    total_timesteps | 8100      |
# | train/             |           |
# |    actor_loss      | 9.37e+18  |
# |    critic_loss     | inf       |
# |    ent_coef        | 2.24e+17  |
# |    ent_coef_loss   | -1.51e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 7999      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.939     |
# | time/              |           |
# |    episodes        | 82        |
# |    fps             | 12        |
# |    time_elapsed    | 641       |
# |    total_timesteps | 8200      |
# | train/             |           |
# |    actor_loss      | 1.54e+19  |
# |    critic_loss     | inf       |
# |    ent_coef        | 3.69e+17  |
# |    ent_coef_loss   | -1.52e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.94      |
# | time/              |           |
# |    episodes        | 83        |
# |    fps             | 12        |
# |    time_elapsed    | 649       |
# |    total_timesteps | 8300      |
# | train/             |           |
# |    actor_loss      | 2.53e+19  |
# |    critic_loss     | inf       |
# |    ent_coef        | 6.09e+17  |
# |    ent_coef_loss   | -1.54e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8199      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.94      |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 12        |
# |    time_elapsed    | 657       |
# |    total_timesteps | 8400      |
# | train/             |           |
# |    actor_loss      | 4.2e+19   |
# |    critic_loss     | inf       |
# |    ent_coef        | 1e+18     |
# |    ent_coef_loss   | -1.57e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.941     |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 12        |
# |    time_elapsed    | 665       |
# |    total_timesteps | 8500      |
# | train/             |           |
# |    actor_loss      | 6.91e+19  |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.65e+18  |
# |    ent_coef_loss   | -1.59e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8399      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.942    |
# | time/              |          |
# |    episodes        | 86       |
# |    fps             | 12       |
# |    time_elapsed    | 673      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | 1.13e+20 |
# |    critic_loss     | inf      |
# |    ent_coef        | 2.73e+18 |
# |    ent_coef_loss   | -1.6e+03 |
# |    learning_rate   | 0.005    |
# |    n_updates       | 8499     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.943     |
# | time/              |           |
# |    episodes        | 87        |
# |    fps             | 12        |
# |    time_elapsed    | 682       |
# |    total_timesteps | 8700      |
# | train/             |           |
# |    actor_loss      | 1.87e+20  |
# |    critic_loss     | inf       |
# |    ent_coef        | 4.5e+18   |
# |    ent_coef_loss   | -1.62e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8599      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.943     |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 12        |
# |    time_elapsed    | 690       |
# |    total_timesteps | 8800      |
# | train/             |           |
# |    actor_loss      | 3.11e+20  |
# |    critic_loss     | inf       |
# |    ent_coef        | 7.41e+18  |
# |    ent_coef_loss   | -1.65e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.944     |
# | time/              |           |
# |    episodes        | 89        |
# |    fps             | 12        |
# |    time_elapsed    | 698       |
# |    total_timesteps | 8900      |
# | train/             |           |
# |    actor_loss      | 5.1e+20   |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.22e+19  |
# |    ent_coef_loss   | -1.66e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8799      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.944     |
# | time/              |           |
# |    episodes        | 90        |
# |    fps             | 12        |
# |    time_elapsed    | 706       |
# |    total_timesteps | 9000      |
# | train/             |           |
# |    actor_loss      | 8.37e+20  |
# |    critic_loss     | inf       |
# |    ent_coef        | 2.02e+19  |
# |    ent_coef_loss   | -1.67e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.945     |
# | time/              |           |
# |    episodes        | 91        |
# |    fps             | 12        |
# |    time_elapsed    | 715       |
# |    total_timesteps | 9100      |
# | train/             |           |
# |    actor_loss      | 1.39e+21  |
# |    critic_loss     | inf       |
# |    ent_coef        | 3.32e+19  |
# |    ent_coef_loss   | -1.69e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 8999      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.946     |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 12        |
# |    time_elapsed    | 722       |
# |    total_timesteps | 9200      |
# | train/             |           |
# |    actor_loss      | 2.28e+21  |
# |    critic_loss     | inf       |
# |    ent_coef        | 5.48e+19  |
# |    ent_coef_loss   | -1.71e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.946     |
# | time/              |           |
# |    episodes        | 93        |
# |    fps             | 12        |
# |    time_elapsed    | 731       |
# |    total_timesteps | 9300      |
# | train/             |           |
# |    actor_loss      | 3.75e+21  |
# |    critic_loss     | inf       |
# |    ent_coef        | 9.03e+19  |
# |    ent_coef_loss   | -1.72e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9199      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.947     |
# | time/              |           |
# |    episodes        | 94        |
# |    fps             | 12        |
# |    time_elapsed    | 739       |
# |    total_timesteps | 9400      |
# | train/             |           |
# |    actor_loss      | 6.19e+21  |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.49e+20  |
# |    ent_coef_loss   | -1.74e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.947     |
# | time/              |           |
# |    episodes        | 95        |
# |    fps             | 12        |
# |    time_elapsed    | 747       |
# |    total_timesteps | 9500      |
# | train/             |           |
# |    actor_loss      | 1.01e+22  |
# |    critic_loss     | inf       |
# |    ent_coef        | 2.46e+20  |
# |    ent_coef_loss   | -1.75e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9399      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.948     |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 12        |
# |    time_elapsed    | 755       |
# |    total_timesteps | 9600      |
# | train/             |           |
# |    actor_loss      | 1.69e+22  |
# |    critic_loss     | inf       |
# |    ent_coef        | 4.05e+20  |
# |    ent_coef_loss   | -1.79e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.948     |
# | time/              |           |
# |    episodes        | 97        |
# |    fps             | 12        |
# |    time_elapsed    | 763       |
# |    total_timesteps | 9700      |
# | train/             |           |
# |    actor_loss      | 2.77e+22  |
# |    critic_loss     | inf       |
# |    ent_coef        | 6.67e+20  |
# |    ent_coef_loss   | -1.79e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9599      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.949     |
# | time/              |           |
# |    episodes        | 98        |
# |    fps             | 12        |
# |    time_elapsed    | 771       |
# |    total_timesteps | 9800      |
# | train/             |           |
# |    actor_loss      | 4.59e+22  |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.1e+21   |
# |    ent_coef_loss   | -1.83e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.949     |
# | time/              |           |
# |    episodes        | 99        |
# |    fps             | 12        |
# |    time_elapsed    | 779       |
# |    total_timesteps | 9900      |
# | train/             |           |
# |    actor_loss      | 7.55e+22  |
# |    critic_loss     | inf       |
# |    ent_coef        | 1.81e+21  |
# |    ent_coef_loss   | -1.84e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9799      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 100       |
# |    ep_rew_mean     | 0.95      |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 12        |
# |    time_elapsed    | 787       |
# |    total_timesteps | 10000     |
# | train/             |           |
# |    actor_loss      | 1.25e+23  |
# |    critic_loss     | inf       |
# |    ent_coef        | 2.99e+21  |
# |    ent_coef_loss   | -1.86e+03 |
# |    learning_rate   | 0.005     |
# |    n_updates       | 9899      |
# ----------------------------------

# %% [markdown]
# - TD3

# %%
del env
env = gym.make('EHREnv-v0', model='lstm', sofa=5)

# %%
td3 = sb3.TD3("MlpPolicy", 
                env, 
                learning_rate=0.01,
                learning_starts=100,
                buffer_size=100,
                batch_size=64,
                train_freq=1,
                verbose=1, 
                tensorboard_log="./tensorboard/EHREnv-v0/",
                device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
td3.learn(total_timesteps=10000, progress_bar=False, log_interval=1, tb_log_name="TD3")
# Out:
# Logging to ./tensorboard/EHREnv-v0/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 21       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 19       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 416      |
# |    critic_loss     | 5.89e+04 |
# |    learning_rate   | 0.01     |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.667    |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 18       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 300      |
# | train/             |          |
# |    actor_loss      | 389      |
# |    critic_loss     | 3.46     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 199      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.75     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 18       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 396      |
# |    critic_loss     | 0.0399   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 17       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 3.16     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.833    |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 17       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 415      |
# |    critic_loss     | 2.26     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.857    |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 17       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 700      |
# | train/             |          |
# |    actor_loss      | 420      |
# |    critic_loss     | 0.153    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.875    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 17       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 422      |
# |    critic_loss     | 0.0503   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.889    |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 17       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 423      |
# |    critic_loss     | 0.0588   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.9      |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 17       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 423      |
# |    critic_loss     | 0.201    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.909    |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 16       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 1100     |
# | train/             |          |
# |    actor_loss      | 423      |
# |    critic_loss     | 0.632    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.917    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 16       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 423      |
# |    critic_loss     | 0.0213   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.923    |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 16       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 1300     |
# | train/             |          |
# |    actor_loss      | 422      |
# |    critic_loss     | 0.0884   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.929    |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 15       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | 421      |
# |    critic_loss     | 0.294    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.933    |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 15       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | 420      |
# |    critic_loss     | 0.021    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.938    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 15       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | 419      |
# |    critic_loss     | 0.00912  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.941    |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 15       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 1700     |
# | train/             |          |
# |    actor_loss      | 418      |
# |    critic_loss     | 0.0391   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.944    |
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 15       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 417      |
# |    critic_loss     | 0.00516  |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.947    |
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 15       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 1900     |
# | train/             |          |
# |    actor_loss      | 416      |
# |    critic_loss     | 0.036    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.95     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 15       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 415      |
# |    critic_loss     | 0.0154   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.952    |
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 14       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 2100     |
# | train/             |          |
# |    actor_loss      | 414      |
# |    critic_loss     | 0.0117   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.955    |
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 14       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | 413      |
# |    critic_loss     | 0.0199   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.957    |
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 14       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 2300     |
# | train/             |          |
# |    actor_loss      | 412      |
# |    critic_loss     | 0.0117   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.958    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 14       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 411      |
# |    critic_loss     | 0.0354   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.96     |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 14       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | 410      |
# |    critic_loss     | 0.0168   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.962    |
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 14       |
# |    time_elapsed    | 177      |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | 409      |
# |    critic_loss     | 3.54     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.963    |
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 14       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 410      |
# |    critic_loss     | 0.939    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.964    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 14       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 0.576    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.966    |
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 14       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 2900     |
# | train/             |          |
# |    actor_loss      | 410      |
# |    critic_loss     | 12       |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.967    |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 14       |
# |    time_elapsed    | 207      |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 0.0753   |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.968    |
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 14       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 3100     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 5.39     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.969    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 14       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 4.25     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.97     |
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 14       |
# |    time_elapsed    | 229      |
# |    total_timesteps | 3300     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 0.924    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.971    |
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 14       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | 411      |
# |    critic_loss     | 24.8     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.971    |
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 14       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 3500     |
# | train/             |          |
# |    actor_loss      | 400      |
# |    critic_loss     | 42.9     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.972    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 14       |
# |    time_elapsed    | 251      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 0.272    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.973    |
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 14       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 3700     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 1.53     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.974    |
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 14       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 14.8     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.974    |
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 14       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 3900     |
# | train/             |          |
# |    actor_loss      | 405      |
# |    critic_loss     | 7.31     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.975    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 14       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 410      |
# |    critic_loss     | 19.3     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.976    |
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 14       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 4100     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.976    |
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 14       |
# |    time_elapsed    | 295      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 0.302    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.977    |
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 14       |
# |    time_elapsed    | 302      |
# |    total_timesteps | 4300     |
# | train/             |          |
# |    actor_loss      | 405      |
# |    critic_loss     | 62.1     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.977    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 14       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | 405      |
# |    critic_loss     | 3.05     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.978    |
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 14       |
# |    time_elapsed    | 317      |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 3.35     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.978    |
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 14       |
# |    time_elapsed    | 324      |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | 407      |
# |    critic_loss     | 8.78     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.979    |
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 14       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 4700     |
# | train/             |          |
# |    actor_loss      | 405      |
# |    critic_loss     | 6.89     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.979    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 14       |
# |    time_elapsed    | 339      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 403      |
# |    critic_loss     | 7.64     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.98     |
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 14       |
# |    time_elapsed    | 346      |
# |    total_timesteps | 4900     |
# | train/             |          |
# |    actor_loss      | 402      |
# |    critic_loss     | 106      |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.98     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 14       |
# |    time_elapsed    | 354      |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 405      |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.98     |
# | time/              |          |
# |    episodes        | 51       |
# |    fps             | 14       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 5100     |
# | train/             |          |
# |    actor_loss      | 404      |
# |    critic_loss     | 1.23     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.981    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 14       |
# |    time_elapsed    | 368      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | 403      |
# |    critic_loss     | 5.61     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.981    |
# | time/              |          |
# |    episodes        | 53       |
# |    fps             | 14       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 5300     |
# | train/             |          |
# |    actor_loss      | 406      |
# |    critic_loss     | 64.7     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.981    |
# | time/              |          |
# |    episodes        | 54       |
# |    fps             | 14       |
# |    time_elapsed    | 383      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | 400      |
# |    critic_loss     | 6.85     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.982    |
# | time/              |          |
# |    episodes        | 55       |
# |    fps             | 14       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 5500     |
# | train/             |          |
# |    actor_loss      | 400      |
# |    critic_loss     | 8.41     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.982    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 14       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 399      |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.982    |
# | time/              |          |
# |    episodes        | 57       |
# |    fps             | 14       |
# |    time_elapsed    | 405      |
# |    total_timesteps | 5700     |
# | train/             |          |
# |    actor_loss      | 402      |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.983    |
# | time/              |          |
# |    episodes        | 58       |
# |    fps             | 14       |
# |    time_elapsed    | 412      |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | 397      |
# |    critic_loss     | 0.369    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.983    |
# | time/              |          |
# |    episodes        | 59       |
# |    fps             | 14       |
# |    time_elapsed    | 419      |
# |    total_timesteps | 5900     |
# | train/             |          |
# |    actor_loss      | 400      |
# |    critic_loss     | 13       |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.983    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 14       |
# |    time_elapsed    | 426      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | 396      |
# |    critic_loss     | 0.126    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.984    |
# | time/              |          |
# |    episodes        | 61       |
# |    fps             | 14       |
# |    time_elapsed    | 434      |
# |    total_timesteps | 6100     |
# | train/             |          |
# |    actor_loss      | 395      |
# |    critic_loss     | 2.34     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 5999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.984    |
# | time/              |          |
# |    episodes        | 62       |
# |    fps             | 14       |
# |    time_elapsed    | 441      |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | 395      |
# |    critic_loss     | 4.36     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.984    |
# | time/              |          |
# |    episodes        | 63       |
# |    fps             | 14       |
# |    time_elapsed    | 448      |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | 395      |
# |    critic_loss     | 0.627    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.984    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 14       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 393      |
# |    critic_loss     | 3.46     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.985    |
# | time/              |          |
# |    episodes        | 65       |
# |    fps             | 14       |
# |    time_elapsed    | 463      |
# |    total_timesteps | 6500     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 4.35     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.985    |
# | time/              |          |
# |    episodes        | 66       |
# |    fps             | 14       |
# |    time_elapsed    | 470      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 0.682    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.985    |
# | time/              |          |
# |    episodes        | 67       |
# |    fps             | 14       |
# |    time_elapsed    | 478      |
# |    total_timesteps | 6700     |
# | train/             |          |
# |    actor_loss      | 394      |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.985    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 14       |
# |    time_elapsed    | 485      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | 391      |
# |    critic_loss     | 3.11     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 69       |
# |    fps             | 13       |
# |    time_elapsed    | 492      |
# |    total_timesteps | 6900     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 1.07     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 13       |
# |    time_elapsed    | 500      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | 393      |
# |    critic_loss     | 4.49     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 71       |
# |    fps             | 13       |
# |    time_elapsed    | 507      |
# |    total_timesteps | 7100     |
# | train/             |          |
# |    actor_loss      | 393      |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 13       |
# |    time_elapsed    | 514      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 0.51     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 73       |
# |    fps             | 13       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 7300     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.986    |
# | time/              |          |
# |    episodes        | 74       |
# |    fps             | 13       |
# |    time_elapsed    | 530      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 0.357    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.987    |
# | time/              |          |
# |    episodes        | 75       |
# |    fps             | 13       |
# |    time_elapsed    | 537      |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | 389      |
# |    critic_loss     | 0.32     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.987    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 13       |
# |    time_elapsed    | 544      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 0.716    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.987    |
# | time/              |          |
# |    episodes        | 77       |
# |    fps             | 13       |
# |    time_elapsed    | 552      |
# |    total_timesteps | 7700     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.987    |
# | time/              |          |
# |    episodes        | 78       |
# |    fps             | 13       |
# |    time_elapsed    | 559      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 0.747    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.987    |
# | time/              |          |
# |    episodes        | 79       |
# |    fps             | 13       |
# |    time_elapsed    | 567      |
# |    total_timesteps | 7900     |
# | train/             |          |
# |    actor_loss      | 388      |
# |    critic_loss     | 1.08     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 13       |
# |    time_elapsed    | 574      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 5.53     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 81       |
# |    fps             | 13       |
# |    time_elapsed    | 581      |
# |    total_timesteps | 8100     |
# | train/             |          |
# |    actor_loss      | 391      |
# |    critic_loss     | 2.8      |
# |    learning_rate   | 0.01     |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 82       |
# |    fps             | 13       |
# |    time_elapsed    | 589      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 2.19     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 83       |
# |    fps             | 13       |
# |    time_elapsed    | 596      |
# |    total_timesteps | 8300     |
# | train/             |          |
# |    actor_loss      | 389      |
# |    critic_loss     | 0.622    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 13       |
# |    time_elapsed    | 604      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | 390      |
# |    critic_loss     | 1.92     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 85       |
# |    fps             | 13       |
# |    time_elapsed    | 611      |
# |    total_timesteps | 8500     |
# | train/             |          |
# |    actor_loss      | 388      |
# |    critic_loss     | 8        |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.988    |
# | time/              |          |
# |    episodes        | 86       |
# |    fps             | 13       |
# |    time_elapsed    | 618      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | 386      |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 87       |
# |    fps             | 13       |
# |    time_elapsed    | 626      |
# |    total_timesteps | 8700     |
# | train/             |          |
# |    actor_loss      | 389      |
# |    critic_loss     | 12.5     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 13       |
# |    time_elapsed    | 633      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | 386      |
# |    critic_loss     | 9.97     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 89       |
# |    fps             | 13       |
# |    time_elapsed    | 640      |
# |    total_timesteps | 8900     |
# | train/             |          |
# |    actor_loss      | 387      |
# |    critic_loss     | 12.7     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 13       |
# |    time_elapsed    | 648      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 391      |
# |    critic_loss     | 65.9     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 91       |
# |    fps             | 13       |
# |    time_elapsed    | 655      |
# |    total_timesteps | 9100     |
# | train/             |          |
# |    actor_loss      | 386      |
# |    critic_loss     | 23.4     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 8999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 13       |
# |    time_elapsed    | 663      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | 392      |
# |    critic_loss     | 79.2     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 93       |
# |    fps             | 13       |
# |    time_elapsed    | 670      |
# |    total_timesteps | 9300     |
# | train/             |          |
# |    actor_loss      | 381      |
# |    critic_loss     | 2.73     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 94       |
# |    fps             | 13       |
# |    time_elapsed    | 678      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | 381      |
# |    critic_loss     | 1.75     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.989    |
# | time/              |          |
# |    episodes        | 95       |
# |    fps             | 13       |
# |    time_elapsed    | 685      |
# |    total_timesteps | 9500     |
# | train/             |          |
# |    actor_loss      | 381      |
# |    critic_loss     | 9.98     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 13       |
# |    time_elapsed    | 693      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | 381      |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 97       |
# |    fps             | 13       |
# |    time_elapsed    | 700      |
# |    total_timesteps | 9700     |
# | train/             |          |
# |    actor_loss      | 378      |
# |    critic_loss     | 0.335    |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 98       |
# |    fps             | 13       |
# |    time_elapsed    | 707      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | 373      |
# |    critic_loss     | 30.2     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 99       |
# |    fps             | 13       |
# |    time_elapsed    | 714      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | 375      |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 13       |
# |    time_elapsed    | 722      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 376      |
# |    critic_loss     | 2.14     |
# |    learning_rate   | 0.01     |
# |    n_updates       | 9899     |
# ---------------------------------

# %% [markdown]
# - A2C

# %%
del env
env = gym.make('EHREnv-v0', model='lstm', sofa=5)

# %%
a2c = sb3.A2C("MlpPolicy", 
                env, 
                learning_rate=0.005,
                n_steps=100,
                verbose=1, 
                tensorboard_log="./tensorboard/EHREnv-v0/",
                device='cpu')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
a2c.learn(total_timesteps=10000, progress_bar=False, log_interval=1, tb_log_name="A2C")
# Out:
# Logging to ./tensorboard/EHREnv-v0/A2C_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -6       |
# | time/              |          |
# |    fps             | 18       |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 100      |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -7       |
# | time/                 |          |
# |    fps                | 18       |
# |    iterations         | 2        |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 200      |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | -0.45    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 1        |
# |    policy_loss        | -11.1    |
# |    std                | 0.979    |
# |    value_loss         | 5.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -5       |
# | time/                 |          |
# |    fps                | 19       |
# |    iterations         | 3        |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 300      |
# | train/                |          |
# |    entropy_loss       | -5.59    |
# |    explained_variance | -4.22    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 2        |
# |    policy_loss        | -15.7    |
# |    std                | 0.982    |
# |    value_loss         | 15.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -4.25    |
# | time/                 |          |
# |    fps                | 20       |
# |    iterations         | 4        |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 400      |
# | train/                |          |
# |    entropy_loss       | -5.6     |
# |    explained_variance | -4.2     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 3        |
# |    policy_loss        | 18.3     |
# |    std                | 0.989    |
# |    value_loss         | 18.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -4.4     |
# | time/                 |          |
# |    fps                | 20       |
# |    iterations         | 5        |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -5.62    |
# |    explained_variance | -0.402   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 4        |
# |    policy_loss        | 10.6     |
# |    std                | 0.982    |
# |    value_loss         | 5.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -4.17    |
# | time/                 |          |
# |    fps                | 20       |
# |    iterations         | 6        |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 600      |
# | train/                |          |
# |    entropy_loss       | -5.59    |
# |    explained_variance | 0.454    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 5        |
# |    policy_loss        | 0.719    |
# |    std                | 0.972    |
# |    value_loss         | 1.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -4       |
# | time/                 |          |
# |    fps                | 20       |
# |    iterations         | 7        |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 700      |
# | train/                |          |
# |    entropy_loss       | -5.55    |
# |    explained_variance | 0.143    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 6        |
# |    policy_loss        | -1.55    |
# |    std                | 0.996    |
# |    value_loss         | 2.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.62    |
# | time/                 |          |
# |    fps                | 20       |
# |    iterations         | 8        |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 800      |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 7        |
# |    policy_loss        | 2.63     |
# |    std                | 1.01     |
# |    value_loss         | 1.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.56    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 9        |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 900      |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.595    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 8        |
# |    policy_loss        | 2.97     |
# |    std                | 1.01     |
# |    value_loss         | 1.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.5     |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 10       |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -5.7     |
# |    explained_variance | 0.0913   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 9        |
# |    policy_loss        | -7.26    |
# |    std                | 1.02     |
# |    value_loss         | 4.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.91    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 11       |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 1100     |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | 0.428    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 10       |
# |    policy_loss        | -1.21    |
# |    std                | 1.02     |
# |    value_loss         | 1.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.67    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 12       |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 1200     |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | 0.136    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 11       |
# |    policy_loss        | 11.3     |
# |    std                | 1.02     |
# |    value_loss         | 7.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.62    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 13       |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 1300     |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.15     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 12       |
# |    policy_loss        | 7.6      |
# |    std                | 1.02     |
# |    value_loss         | 3.92     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.57    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 14       |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 1400     |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | -0.488   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 13       |
# |    policy_loss        | 8.13     |
# |    std                | 1.03     |
# |    value_loss         | 3.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.67    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 15       |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | -4.37    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 14       |
# |    policy_loss        | -13.5    |
# |    std                | 1.03     |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.56    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 16       |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 1600     |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | -0.64    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 15       |
# |    policy_loss        | -11.8    |
# |    std                | 1.04     |
# |    value_loss         | 13.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.53    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 17       |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 1700     |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.476    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 16       |
# |    policy_loss        | -1.11    |
# |    std                | 1.04     |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.33    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 18       |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 1800     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.645    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 17       |
# |    policy_loss        | 0.64     |
# |    std                | 1.03     |
# |    value_loss         | 1.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.58    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 19       |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 1900     |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | 0.432    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 18       |
# |    policy_loss        | 8.54     |
# |    std                | 1.03     |
# |    value_loss         | 2.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.5     |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 20       |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.655    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 19       |
# |    policy_loss        | -11.3    |
# |    std                | 1.03     |
# |    value_loss         | 5.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.29    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 21       |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 2100     |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.703    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 20       |
# |    policy_loss        | 3.74     |
# |    std                | 1.02     |
# |    value_loss         | 0.845    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.36    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 22       |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 2200     |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | 0.6      |
# |    learning_rate      | 0.005    |
# |    n_updates          | 21       |
# |    policy_loss        | 8.63     |
# |    std                | 1.02     |
# |    value_loss         | 3.58     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.35    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 23       |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 2300     |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | -1.5     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 22       |
# |    policy_loss        | -16.7    |
# |    std                | 1.02     |
# |    value_loss         | 17.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.5     |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 24       |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 2400     |
# | train/                |          |
# |    entropy_loss       | -5.73    |
# |    explained_variance | 0.391    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 23       |
# |    policy_loss        | -2.83    |
# |    std                | 1.02     |
# |    value_loss         | 1.82     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.6     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 25       |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.0126   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 24       |
# |    policy_loss        | -16.4    |
# |    std                | 1.02     |
# |    value_loss         | 10.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.54    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 26       |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 2600     |
# | train/                |          |
# |    entropy_loss       | -5.73    |
# |    explained_variance | 0.0431   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 25       |
# |    policy_loss        | -3.23    |
# |    std                | 1.03     |
# |    value_loss         | 3.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.56    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 27       |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 2700     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | -0.0274  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 26       |
# |    policy_loss        | -1.48    |
# |    std                | 1.04     |
# |    value_loss         | 0.884    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.5     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 28       |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 2800     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.0736   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 27       |
# |    policy_loss        | -2.67    |
# |    std                | 1.04     |
# |    value_loss         | 1.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.55    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 29       |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 2900     |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | -0.00223 |
# |    learning_rate      | 0.005    |
# |    n_updates          | 28       |
# |    policy_loss        | -2.68    |
# |    std                | 1.03     |
# |    value_loss         | 2.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.63    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 30       |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | -0.152   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 29       |
# |    policy_loss        | 4.57     |
# |    std                | 1.04     |
# |    value_loss         | 1.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.68    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 31       |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 3100     |
# | train/                |          |
# |    entropy_loss       | -5.8     |
# |    explained_variance | 0.0267   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 30       |
# |    policy_loss        | -7.27    |
# |    std                | 1.04     |
# |    value_loss         | 2.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.75    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 32       |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 3200     |
# | train/                |          |
# |    entropy_loss       | -5.82    |
# |    explained_variance | 0.0502   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 31       |
# |    policy_loss        | -3.52    |
# |    std                | 1.04     |
# |    value_loss         | 0.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.85    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 33       |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 3300     |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.0087   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 32       |
# |    policy_loss        | 4.21     |
# |    std                | 1.05     |
# |    value_loss         | 3.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.74    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 34       |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 3400     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 2.98e-05 |
# |    learning_rate      | 0.005    |
# |    n_updates          | 33       |
# |    policy_loss        | -7.47    |
# |    std                | 1.05     |
# |    value_loss         | 4.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 35       |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -5.82    |
# |    explained_variance | 0.0382   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 34       |
# |    policy_loss        | 14.2     |
# |    std                | 1.04     |
# |    value_loss         | 7.79     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.83    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 36       |
# |    time_elapsed       | 161      |
# |    total_timesteps    | 3600     |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.0104   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 35       |
# |    policy_loss        | -10.8    |
# |    std                | 1.05     |
# |    value_loss         | 4.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3       |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 37       |
# |    time_elapsed       | 166      |
# |    total_timesteps    | 3700     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 0.0647   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 36       |
# |    policy_loss        | 2.54     |
# |    std                | 1.05     |
# |    value_loss         | 3.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.05    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 38       |
# |    time_elapsed       | 170      |
# |    total_timesteps    | 3800     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.0126   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 37       |
# |    policy_loss        | -9.85    |
# |    std                | 1.05     |
# |    value_loss         | 5.14     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.03    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 39       |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 3900     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.123    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 38       |
# |    policy_loss        | -1.88    |
# |    std                | 1.05     |
# |    value_loss         | 1.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.08    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 40       |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.0341   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 39       |
# |    policy_loss        | 10.5     |
# |    std                | 1.04     |
# |    value_loss         | 5.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.12    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 41       |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 4100     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 0.165    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 40       |
# |    policy_loss        | 0.763    |
# |    std                | 1.03     |
# |    value_loss         | 1.75     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.1     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 42       |
# |    time_elapsed       | 188      |
# |    total_timesteps    | 4200     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.104    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 41       |
# |    policy_loss        | -1.87    |
# |    std                | 1.03     |
# |    value_loss         | 2.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.14    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 43       |
# |    time_elapsed       | 193      |
# |    total_timesteps    | 4300     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.00158  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 42       |
# |    policy_loss        | 5.25     |
# |    std                | 1.03     |
# |    value_loss         | 2.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.18    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 44       |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 4400     |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | 0.191    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 43       |
# |    policy_loss        | -1.96    |
# |    std                | 1.04     |
# |    value_loss         | 1.75     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.31    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 45       |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -5.82    |
# |    explained_variance | 0.197    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 44       |
# |    policy_loss        | -3.8     |
# |    std                | 1.04     |
# |    value_loss         | 1.21     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.37    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 46       |
# |    time_elapsed       | 206      |
# |    total_timesteps    | 4600     |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 45       |
# |    policy_loss        | -4.19    |
# |    std                | 1.05     |
# |    value_loss         | 3.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.45    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 47       |
# |    time_elapsed       | 211      |
# |    total_timesteps    | 4700     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 46       |
# |    policy_loss        | 1.37     |
# |    std                | 1.05     |
# |    value_loss         | 2.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.4     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 48       |
# |    time_elapsed       | 216      |
# |    total_timesteps    | 4800     |
# | train/                |          |
# |    entropy_loss       | -5.85    |
# |    explained_variance | 0.197    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 47       |
# |    policy_loss        | -5.02    |
# |    std                | 1.05     |
# |    value_loss         | 2.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.47    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 49       |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 4900     |
# | train/                |          |
# |    entropy_loss       | -5.85    |
# |    explained_variance | -0.0972  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 48       |
# |    policy_loss        | 11.6     |
# |    std                | 1.05     |
# |    value_loss         | 4.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.48    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 50       |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -5.85    |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 49       |
# |    policy_loss        | -0.836   |
# |    std                | 1.05     |
# |    value_loss         | 3.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.53    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 51       |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 5100     |
# | train/                |          |
# |    entropy_loss       | -5.85    |
# |    explained_variance | -0.159   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 50       |
# |    policy_loss        | 7.38     |
# |    std                | 1.05     |
# |    value_loss         | 3.55     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.48    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 52       |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 5200     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 0.209    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 51       |
# |    policy_loss        | -4.49    |
# |    std                | 1.05     |
# |    value_loss         | 3.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.53    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 53       |
# |    time_elapsed       | 238      |
# |    total_timesteps    | 5300     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | -0.702   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 52       |
# |    policy_loss        | 12.8     |
# |    std                | 1.05     |
# |    value_loss         | 6        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.61    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 54       |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 5400     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 0.294    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 53       |
# |    policy_loss        | -1.8     |
# |    std                | 1.05     |
# |    value_loss         | 1.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.6     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 55       |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.00168  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 54       |
# |    policy_loss        | -7.1     |
# |    std                | 1.05     |
# |    value_loss         | 2.52     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.54    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 56       |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 5600     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.0778   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 55       |
# |    policy_loss        | 1.41     |
# |    std                | 1.05     |
# |    value_loss         | 0.985    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.54    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 57       |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 5700     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 56       |
# |    policy_loss        | 13.1     |
# |    std                | 1.06     |
# |    value_loss         | 5.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.52    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 58       |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 5800     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | -0.0704  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 57       |
# |    policy_loss        | 2.32     |
# |    std                | 1.06     |
# |    value_loss         | 1.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.47    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 59       |
# |    time_elapsed       | 265      |
# |    total_timesteps    | 5900     |
# | train/                |          |
# |    entropy_loss       | -5.87    |
# |    explained_variance | 0.0286   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 58       |
# |    policy_loss        | 1.74     |
# |    std                | 1.05     |
# |    value_loss         | 0.844    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.43    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 60       |
# |    time_elapsed       | 269      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.182    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 59       |
# |    policy_loss        | 5.02     |
# |    std                | 1.05     |
# |    value_loss         | 1.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.36    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 61       |
# |    time_elapsed       | 275      |
# |    total_timesteps    | 6100     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | -0.104   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 60       |
# |    policy_loss        | 0.556    |
# |    std                | 1.06     |
# |    value_loss         | 0.283    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.32    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 62       |
# |    time_elapsed       | 281      |
# |    total_timesteps    | 6200     |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | -0.46    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 61       |
# |    policy_loss        | 2.18     |
# |    std                | 1.06     |
# |    value_loss         | 0.573    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.27    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 63       |
# |    time_elapsed       | 285      |
# |    total_timesteps    | 6300     |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.226    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 62       |
# |    policy_loss        | 0.474    |
# |    std                | 1.09     |
# |    value_loss         | 0.458    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.22    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 64       |
# |    time_elapsed       | 290      |
# |    total_timesteps    | 6400     |
# | train/                |          |
# |    entropy_loss       | -5.98    |
# |    explained_variance | 0.146    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 63       |
# |    policy_loss        | 0.35     |
# |    std                | 1.08     |
# |    value_loss         | 0.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.17    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 65       |
# |    time_elapsed       | 294      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -5.95    |
# |    explained_variance | 0.188    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 64       |
# |    policy_loss        | -1.05    |
# |    std                | 1.08     |
# |    value_loss         | 0.307    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.12    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 66       |
# |    time_elapsed       | 299      |
# |    total_timesteps    | 6600     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.0664   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 65       |
# |    policy_loss        | 1.79     |
# |    std                | 1.08     |
# |    value_loss         | 0.568    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.07    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 67       |
# |    time_elapsed       | 303      |
# |    total_timesteps    | 6700     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | -0.382   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 66       |
# |    policy_loss        | -2.71    |
# |    std                | 1.08     |
# |    value_loss         | 0.693    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3       |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 68       |
# |    time_elapsed       | 308      |
# |    total_timesteps    | 6800     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.071    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 67       |
# |    policy_loss        | 1.06     |
# |    std                | 1.07     |
# |    value_loss         | 0.226    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.97    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 69       |
# |    time_elapsed       | 313      |
# |    total_timesteps    | 6900     |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.0214   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 68       |
# |    policy_loss        | 4.69     |
# |    std                | 1.07     |
# |    value_loss         | 1.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.94    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 70       |
# |    time_elapsed       | 317      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -5.88    |
# |    explained_variance | 0.186    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 69       |
# |    policy_loss        | -1.76    |
# |    std                | 1.07     |
# |    value_loss         | 0.5      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.92    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 71       |
# |    time_elapsed       | 321      |
# |    total_timesteps    | 7100     |
# | train/                |          |
# |    entropy_loss       | -5.88    |
# |    explained_variance | 0.0449   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 70       |
# |    policy_loss        | -5.15    |
# |    std                | 1.07     |
# |    value_loss         | 1.14     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.88    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 72       |
# |    time_elapsed       | 326      |
# |    total_timesteps    | 7200     |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.063    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 71       |
# |    policy_loss        | -2.9     |
# |    std                | 1.07     |
# |    value_loss         | 0.624    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.86    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 73       |
# |    time_elapsed       | 331      |
# |    total_timesteps    | 7300     |
# ...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.94    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 77       |
# |    time_elapsed       | 350      |
# |    total_timesteps    | 7700     |
# | train/                |          |
# |    entropy_loss       | -5.87    |
# |    explained_variance | 0.199    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 76       |
# |    policy_loss        | -5.85    |
# |    std                | 1.06     |
# |    value_loss         | 2.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.95    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 78       |
# |    time_elapsed       | 355      |
# |    total_timesteps    | 7800     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.161    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 77       |
# |    policy_loss        | -4.33    |
# |    std                | 1.06     |
# |    value_loss         | 1.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.94    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 79       |
# |    time_elapsed       | 360      |
# |    total_timesteps    | 7900     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.351    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 78       |
# |    policy_loss        | 2.55     |
# |    std                | 1.06     |
# |    value_loss         | 2.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.98    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 80       |
# |    time_elapsed       | 364      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.25     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 79       |
# |    policy_loss        | 11.7     |
# |    std                | 1.06     |
# |    value_loss         | 7.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.99    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 81       |
# |    time_elapsed       | 369      |
# |    total_timesteps    | 8100     |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.36     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 80       |
# |    policy_loss        | -1.5     |
# |    std                | 1.08     |
# |    value_loss         | 1.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3       |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 82       |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 8200     |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.454    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 81       |
# |    policy_loss        | 2.02     |
# |    std                | 1.08     |
# |    value_loss         | 1.21     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -3.02    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 83       |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 8300     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.419    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 82       |
# |    policy_loss        | 5.65     |
# |    std                | 1.08     |
# |    value_loss         | 3.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.96    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 84       |
# |    time_elapsed       | 382      |
# |    total_timesteps    | 8400     |
# | train/                |          |
# |    entropy_loss       | -5.94    |
# |    explained_variance | -0.639   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 83       |
# |    policy_loss        | -6.7     |
# |    std                | 1.08     |
# |    value_loss         | 3.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.94    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 85       |
# |    time_elapsed       | 386      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -5.94    |
# |    explained_variance | 0.328    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 84       |
# |    policy_loss        | 12.7     |
# |    std                | 1.08     |
# |    value_loss         | 5.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.91    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 86       |
# |    time_elapsed       | 391      |
# |    total_timesteps    | 8600     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | -0.546   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 85       |
# |    policy_loss        | -2.27    |
# |    std                | 1.08     |
# |    value_loss         | 1.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.91    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 87       |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 8700     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | -0.627   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 86       |
# |    policy_loss        | 8.6      |
# |    std                | 1.08     |
# |    value_loss         | 4.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.91    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 88       |
# |    time_elapsed       | 400      |
# |    total_timesteps    | 8800     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | -0.0821  |
# |    learning_rate      | 0.005    |
# |    n_updates          | 87       |
# |    policy_loss        | -7.28    |
# |    std                | 1.08     |
# |    value_loss         | 2.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.87    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 89       |
# |    time_elapsed       | 404      |
# |    total_timesteps    | 8900     |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.235    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 88       |
# |    policy_loss        | 2.06     |
# |    std                | 1.08     |
# |    value_loss         | 1.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.83    |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 90       |
# |    time_elapsed       | 409      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.043    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 89       |
# |    policy_loss        | 7.21     |
# |    std                | 1.08     |
# |    value_loss         | 3.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.82    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 91       |
# |    time_elapsed       | 413      |
# |    total_timesteps    | 9100     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.1      |
# |    learning_rate      | 0.005    |
# |    n_updates          | 90       |
# |    policy_loss        | 5.07     |
# |    std                | 1.08     |
# |    value_loss         | 1.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.8     |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 92       |
# |    time_elapsed       | 417      |
# |    total_timesteps    | 9200     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.0944   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 91       |
# |    policy_loss        | -0.0201  |
# |    std                | 1.08     |
# |    value_loss         | 1.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.76    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 93       |
# |    time_elapsed       | 422      |
# |    total_timesteps    | 9300     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.14     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 92       |
# |    policy_loss        | 2.77     |
# |    std                | 1.07     |
# |    value_loss         | 1.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.72    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 94       |
# |    time_elapsed       | 426      |
# |    total_timesteps    | 9400     |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.14     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 93       |
# |    policy_loss        | 3.7      |
# |    std                | 1.07     |
# |    value_loss         | 1.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.71    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 95       |
# |    time_elapsed       | 431      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.0153   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 94       |
# |    policy_loss        | 3.02     |
# |    std                | 1.08     |
# |    value_loss         | 2.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.69    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 96       |
# |    time_elapsed       | 436      |
# |    total_timesteps    | 9600     |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.118    |
# |    learning_rate      | 0.005    |
# |    n_updates          | 95       |
# |    policy_loss        | -4.37    |
# |    std                | 1.08     |
# |    value_loss         | 1.44     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.68    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 97       |
# |    time_elapsed       | 440      |
# |    total_timesteps    | 9700     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | -0.1     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 96       |
# |    policy_loss        | -3.46    |
# |    std                | 1.08     |
# |    value_loss         | 1.66     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.66    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 98       |
# |    time_elapsed       | 445      |
# |    total_timesteps    | 9800     |
# | train/                |          |
# |    entropy_loss       | -5.94    |
# |    explained_variance | -0.067   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 97       |
# |    policy_loss        | -1.14    |
# |    std                | 1.08     |
# |    value_loss         | 1.4      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.61    |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 99       |
# |    time_elapsed       | 449      |
# |    total_timesteps    | 9900     |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.17     |
# |    learning_rate      | 0.005    |
# |    n_updates          | 98       |
# |    policy_loss        | -1.28    |
# |    std                | 1.08     |
# |    value_loss         | 0.781    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | -2.6     |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 100      |
# |    time_elapsed       | 454      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -5.94    |
# |    explained_variance | -0.101   |
# |    learning_rate      | 0.005    |
# |    n_updates          | 99       |
# |    policy_loss        | 8.4      |
# |    std                | 1.08     |
# |    value_loss         | 2.64     |
# ------------------------------------
